# %% [markdown]
# <a href="https://colab.research.google.com/github/alondraluduena/Modulo_1/blob/main/colab_alondra.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Este es mi primer cuaderno
# Aqui voy a mezclar código markdown con operaciones matemáticas
# - sumar
# - restar
# - multiplicar
# - dividir

# %%
a=3
b=5
print('esta cuenta es muy dificil pero solo muestro el resultado')
(a+b)*b+a
a-b
print('Al final no era tan complicado lol')
# Out:
# [1] "esta cuenta es muy dificil pero solo muestro el resultado"
# [1] 43
# [1] -2
# [1] "Al final no era tan complicado lol"

# %%
a=-10:10
b=a^3
c=3*(a^2)
plot(a,b,main='presión del gas critico',xlab='volumen',ylab='presion',type='S',col='green')
plot(a,c,main='UNICORNIOSSSSSS',xlab='Población de unicornios',ylab='Cant. de visualizaciones',type='c',col='red')
# Out:
# Plot with title “presión del gas critico”
# Plot with title “UNICORNIOSSSSSS”
